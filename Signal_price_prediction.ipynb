# %%
import pandas as pd
import numpy as np

# %%
url = 'quant_dataset.csv'
df = pd.read_csv(url)
df
# Out:
#       Unnamed: 0        Date    Price  Signal1   Signal2   Signal3   Signal4  \
# 0              0  2016-11-30  2198.81  1604.81  1747.755  1223.065  1046.997
# 1              1  2016-11-29  2204.66  1618.66  1754.199  1226.297  1056.146
# 2              2  2016-11-28  2201.72  1623.72  1746.585  1228.043  1054.482
# 3              3  2016-11-25  2213.35  1627.35  1718.271  1228.255  1028.893
# 4              4  2016-11-23  2204.72  1610.72  1719.306  1225.037  1025.879
# ...          ...         ...      ...      ...       ...       ...       ...
# 2995        2995  2005-01-07  1186.20  1384.20  1217.520  1642.076  1437.734
# 2996        2996  2005-01-06  1187.90  1377.90  1210.320  1641.057  1425.951
# 2997        2997  2005-01-05  1183.70  1381.70  1206.000  1641.089  1425.334
# 2998        2998  2005-01-04  1188.00  1378.00  1207.170  1641.369  1422.754
# 2999        2999  2005-01-03  1202.10  1384.10  1200.690  1646.550  1411.759
#
#        Signal5  Signal6   Signal7
# 0     1482.027   2888.8  5157.211
# 1     1485.327   2888.8  5146.420
# 2     1488.624   2904.8  5159.236
# 3     1484.897   2920.8  5168.596
# 4     1481.172   2904.8  5168.150
# ...        ...      ...       ...
# 2995   766.572    264.8  2983.811
# 2996   765.614    248.8  2985.111
# 2997   765.886    248.8  2993.712
# 2998   764.928    248.8  2989.034
# 2999   763.971    232.8  2976.796
#
# [3000 rows x 10 columns]

# %%
df = df.drop('Unnamed: 0', axis=1)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df
# Out:
#               Price  Signal1   Signal2   Signal3   Signal4   Signal5  Signal6  \
# Date
# 2016-11-30  2198.81  1604.81  1747.755  1223.065  1046.997  1482.027   2888.8
# 2016-11-29  2204.66  1618.66  1754.199  1226.297  1056.146  1485.327   2888.8
# 2016-11-28  2201.72  1623.72  1746.585  1228.043  1054.482  1488.624   2904.8
# 2016-11-25  2213.35  1627.35  1718.271  1228.255  1028.893  1484.897   2920.8
# 2016-11-23  2204.72  1610.72  1719.306  1225.037  1025.879  1481.172   2904.8
# ...             ...      ...       ...       ...       ...       ...      ...
# 2005-01-07  1186.20  1384.20  1217.520  1642.076  1437.734   766.572    264.8
# 2005-01-06  1187.90  1377.90  1210.320  1641.057  1425.951   765.614    248.8
# 2005-01-05  1183.70  1381.70  1206.000  1641.089  1425.334   765.886    248.8
# 2005-01-04  1188.00  1378.00  1207.170  1641.369  1422.754   764.928    248.8
# 2005-01-03  1202.10  1384.10  1200.690  1646.550  1411.759   763.971    232.8
#
#              Signal7
# Date
# 2016-11-30  5157.211
# 2016-11-29  5146.420
# 2016-11-28  5159.236
# 2016-11-25  5168.596
# 2016-11-23  5168.150
# ...              ...
# 2005-01-07  2983.811
# 2005-01-06  2985.111
# 2005-01-05  2993.712
# 2005-01-04  2989.034
# 2005-01-03  2976.796
#
# [3000 rows x 8 columns]

# %%
df.interpolate(method='linear', inplace=True)
df
# Out:
#               Price  Signal1   Signal2   Signal3   Signal4   Signal5  Signal6  \
# Date
# 2016-11-30  2198.81  1604.81  1747.755  1223.065  1046.997  1482.027   2888.8
# 2016-11-29  2204.66  1618.66  1754.199  1226.297  1056.146  1485.327   2888.8
# 2016-11-28  2201.72  1623.72  1746.585  1228.043  1054.482  1488.624   2904.8
# 2016-11-25  2213.35  1627.35  1718.271  1228.255  1028.893  1484.897   2920.8
# 2016-11-23  2204.72  1610.72  1719.306  1225.037  1025.879  1481.172   2904.8
# ...             ...      ...       ...       ...       ...       ...      ...
# 2005-01-07  1186.20  1384.20  1217.520  1642.076  1437.734   766.572    264.8
# 2005-01-06  1187.90  1377.90  1210.320  1641.057  1425.951   765.614    248.8
# 2005-01-05  1183.70  1381.70  1206.000  1641.089  1425.334   765.886    248.8
# 2005-01-04  1188.00  1378.00  1207.170  1641.369  1422.754   764.928    248.8
# 2005-01-03  1202.10  1384.10  1200.690  1646.550  1411.759   763.971    232.8
#
#              Signal7
# Date
# 2016-11-30  5157.211
# 2016-11-29  5146.420
# 2016-11-28  5159.236
# 2016-11-25  5168.596
# 2016-11-23  5168.150
# ...              ...
# 2005-01-07  2983.811
# 2005-01-06  2985.111
# 2005-01-05  2993.712
# 2005-01-04  2989.034
# 2005-01-03  2976.796
#
# [3000 rows x 8 columns]

# %%
date_range = pd.date_range('2005-01-03','2016-11-30')
df = df.reindex(date_range).interpolate(method='linear')
df.to_csv('cleaned_data.csv', index=True)
df
# Out:
#                   Price  Signal1   Signal2      Signal3      Signal4  \
# 2005-01-03  1202.100000  1384.10  1200.690  1646.550000  1411.759000
# 2005-01-04  1188.000000  1378.00  1207.170  1641.369000  1422.754000
# 2005-01-05  1183.700000  1381.70  1206.000  1641.089000  1425.334000
# 2005-01-06  1187.900000  1377.90  1210.320  1641.057000  1425.951000
# 2005-01-07  1186.200000  1384.20  1217.520  1642.076000  1437.734000
# ...                 ...      ...       ...          ...          ...
# 2016-11-26  2209.473333  1626.14  1727.709  1228.184333  1037.422667
# 2016-11-27  2205.596667  1624.93  1737.147  1228.113667  1045.952333
# 2016-11-28  2201.720000  1623.72  1746.585  1228.043000  1054.482000
# 2016-11-29  2204.660000  1618.66  1754.199  1226.297000  1056.146000
# 2016-11-30  2198.810000  1604.81  1747.755  1223.065000  1046.997000
#
#                 Signal5      Signal6   Signal7
# 2005-01-03   763.971000   232.800000  2976.796
# 2005-01-04   764.928000   248.800000  2989.034
# 2005-01-05   765.886000   248.800000  2993.712
# 2005-01-06   765.614000   248.800000  2985.111
# 2005-01-07   766.572000   264.800000  2983.811
# ...                 ...          ...       ...
# 2016-11-26  1486.139333  2915.466667  5165.476
# 2016-11-27  1487.381667  2910.133333  5162.356
# 2016-11-28  1488.624000  2904.800000  5159.236
# 2016-11-29  1485.327000  2888.800000  5146.420
# 2016-11-30  1482.027000  2888.800000  5157.211
#
# [4350 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

for col in df.columns:
    df[col].plot()
    plt.title(col)
    plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
results = seasonal_decompose(df['Price'])
results.plot()

# %%
df['day-1'] = df['Price'].shift(+1)
df['day-2'] = df['Price'].shift(+2)
df['day-3'] = df['Price'].shift(+3)
df
# Out:
#                   Price  Signal1   Signal2      Signal3      Signal4  \
# 2005-01-03  1202.100000  1384.10  1200.690  1646.550000  1411.759000
# 2005-01-04  1188.000000  1378.00  1207.170  1641.369000  1422.754000
# 2005-01-05  1183.700000  1381.70  1206.000  1641.089000  1425.334000
# 2005-01-06  1187.900000  1377.90  1210.320  1641.057000  1425.951000
# 2005-01-07  1186.200000  1384.20  1217.520  1642.076000  1437.734000
# ...                 ...      ...       ...          ...          ...
# 2016-11-26  2209.473333  1626.14  1727.709  1228.184333  1037.422667
# 2016-11-27  2205.596667  1624.93  1737.147  1228.113667  1045.952333
# 2016-11-28  2201.720000  1623.72  1746.585  1228.043000  1054.482000
# 2016-11-29  2204.660000  1618.66  1754.199  1226.297000  1056.146000
# 2016-11-30  2198.810000  1604.81  1747.755  1223.065000  1046.997000
#
#                 Signal5      Signal6   Signal7        day-1        day-2  \
# 2005-01-03   763.971000   232.800000  2976.796          NaN          NaN
# 2005-01-04   764.928000   248.800000  2989.034  1202.100000          NaN
# 2005-01-05   765.886000   248.800000  2993.712  1188.000000  1202.100000
# 2005-01-06   765.614000   248.800000  2985.111  1183.700000  1188.000000
# 2005-01-07   766.572000   264.800000  2983.811  1187.900000  1183.700000
# ...                 ...          ...       ...          ...          ...
# 2016-11-26  1486.139333  2915.466667  5165.476  2213.350000  2209.035000
# 2016-11-27  1487.381667  2910.133333  5162.356  2209.473333  2213.350000
# 2016-11-28  1488.624000  2904.800000  5159.236  2205.596667  2209.473333
# 2016-11-29  1485.327000  2888.800000  5146.420  2201.720000  2205.596667
# 2016-11-30  1482.027000  2888.800000  5157.211  2204.660000  2201.720000
#
#                   day-3
# 2005-01-03          NaN
# 2005-01-04          NaN
# 2005-01-05          NaN
# 2005-01-06  1202.100000
# 2005-01-07  1188.000000
# ...                 ...
# 2016-11-26  2204.720000
# 2016-11-27  2209.035000
# 2016-11-28  2213.350000
# 2016-11-29  2209.473333
# 2016-11-30  2205.596667
#
# [4350 rows x 11 columns]

# %%
df = df.dropna()
df
# Out:
#                   Price  Signal1   Signal2      Signal3      Signal4  \
# 2005-01-06  1187.900000  1377.90  1210.320  1641.057000  1425.951000
# 2005-01-07  1186.200000  1384.20  1217.520  1642.076000  1437.734000
# 2005-01-08  1187.533333  1388.20  1216.830  1643.365000  1438.264000
# 2005-01-09  1188.866667  1392.20  1216.140  1644.654000  1438.794000
# 2005-01-10  1190.200000  1396.20  1215.450  1645.943000  1439.324000
# ...                 ...      ...       ...          ...          ...
# 2016-11-26  2209.473333  1626.14  1727.709  1228.184333  1037.422667
# 2016-11-27  2205.596667  1624.93  1737.147  1228.113667  1045.952333
# 2016-11-28  2201.720000  1623.72  1746.585  1228.043000  1054.482000
# 2016-11-29  2204.660000  1618.66  1754.199  1226.297000  1056.146000
# 2016-11-30  2198.810000  1604.81  1747.755  1223.065000  1046.997000
#
#                 Signal5      Signal6      Signal7        day-1        day-2  \
# 2005-01-06   765.614000   248.800000  2985.111000  1183.700000  1188.000000
# 2005-01-07   766.572000   264.800000  2983.811000  1187.900000  1183.700000
# 2005-01-08   766.892000   264.800000  2983.083667  1186.200000  1187.900000
# 2005-01-09   767.212000   264.800000  2982.356333  1187.533333  1186.200000
# 2005-01-10   767.532000   264.800000  2981.629000  1188.866667  1187.533333
# ...                 ...          ...          ...          ...          ...
# 2016-11-26  1486.139333  2915.466667  5165.476000  2213.350000  2209.035000
# 2016-11-27  1487.381667  2910.133333  5162.356000  2209.473333  2213.350000
# 2016-11-28  1488.624000  2904.800000  5159.236000  2205.596667  2209.473333
# 2016-11-29  1485.327000  2888.800000  5146.420000  2201.720000  2205.596667
# 2016-11-30  1482.027000  2888.800000  5157.211000  2204.660000  2201.720000
#
#                   day-3
# 2005-01-06  1202.100000
# 2005-01-07  1188.000000
# 2005-01-08  1183.700000
# 2005-01-09  1187.900000
# 2005-01-10  1186.200000
# ...                 ...
# 2016-11-26  2204.720000
# 2016-11-27  2209.035000
# 2016-11-28  2213.350000
# 2016-11-29  2209.473333
# 2016-11-30  2205.596667
#
# [4347 rows x 11 columns]

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression()

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 100, max_features = 3, random_state = 1)

# %%
X = df.iloc[:, 1:].values.tolist()
Y = df['Price'].tolist()

# %%
X_train, X_test, Y_train, Y_test = X[:-100], X[-100:], Y[:-100], Y[-100:]

model.fit(X_train, Y_train)
pred = model.predict(X_test)
plt.rcParams["figure.figsize"] = (12, 8)
plt.plot(pred, label='Random_Forest_Predictions')
plt.plot(Y_test, label='Actual Price')
plt.legend(loc="upper left")
plt.show()

# %%
lin_model.fit(X_train, Y_train)
lin_pred = lin_model.predict(X_test)
plt.rcParams["figure.figsize"] = (12, 8)
plt.plot(lin_pred, label='Linear_Regression_Predictions')
plt.plot(Y_test, label='Actual Price')
plt.legend(loc="upper left")
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse_rf = sqrt(mean_squared_error(pred, Y_test))
mse_lr = sqrt(mean_squared_error(lin_pred, Y_test))

print("Mean squared error for Random Forest Regressor is: ", mse_rf)
print("Mean squared error for Linear Regressor is: ", mse_lr)
# Out:
# Mean squared error for Random Forest Regressor is:  16.683786064614825
# Mean squared error for Linear Regressor is:  3.1462451779057514
